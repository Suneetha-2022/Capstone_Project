# %%
import requests
import pandas as pd
import numpy as np
import findspark
import pandas as pd
import numpy as np
findspark.init()
from pyspark.sql import SparkSession
from pyspark.sql.functions import*
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType, DoubleType
from pyspark import SparkContext
from pyspark.sql.functions import monotonically_increasing_id
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_transvis = pd.read_json(r'C:\suneetha\Python_labs\Capstone_Project\CreditCard_dataset\cdw_sapp_credit.json', lines=True)
print('Data downloaded and read into a dataframe!')
# Out:
# Data downloaded and read into a dataframe!

# %%
#Calculate Mean of transactions group by Transaction type
mean_trans = df_transvis.groupby("TRANSACTION_TYPE")["TRANSACTION_VALUE"].mean()
#Convert avg_trans series to pandas dataframe
avg_trans_df = mean_trans.to_frame(name="mean_trans")
avg_trans_df
# Out:
#                   mean_trans
# TRANSACTION_TYPE
# Bills              51.217793
# Education          50.915949
# Entertainment      51.085170
# Gas                50.879525
# Grocery            51.466122
# Healthcare         50.643492
# Test               51.071430

# %%
avg_trans_df.plot(kind='bar', figsize=(10, 6), color = 'blue')
plt.xlabel('Transaction_type')
plt.ylabel('Mean of Transactions')
plt.title('Rate of Transactions')
plt.show()
